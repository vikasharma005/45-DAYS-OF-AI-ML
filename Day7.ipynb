# %%
s1 = {}
s1
# Out:
# {}

# %%
type(s1)
# Out:
# dict

# %%
s1 = set()
s1
# Out:
# set()

# %%
type(s1)
# Out:
# set

# %%
data = {-10,100,5,55,"A","a"}
data
# Out:
# {-10, 100, 5, 55, 'A', 'a'}

# %%
ord("😎")
# Out:
# 128526

# %%
char(128524)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-dbe16a59a1be> in <cell line: 1>()
# ----> 1 char(128524)
#
# NameError: name 'char' is not defined

# %%
s1 = {"Sean","Mike","Finn","Allen","Sean","Luke"}
s1
# Out:
# {'Allen', 'Finn', 'Luke', 'Mike', 'Sean'}

# %%
inp = input("Do You Want To Remove Duplicate Values :")
if inp=="Yes":
    l5 = set(l5)
    print("\nSuccessFully..")
    l1 = list(l1)
    print("\nList Is :",l1)
else:
    print("\nOkay !!")
# Out:
# Do You Want To Remove Duplicate Values :y
#
# Okay !!

# %%
s1 = {'Allen', 'Finn', 'Jack', 'Luke', 'Mike', 'Peter'}
s1
# Out:
# {'Allen', 'Finn', 'Jack', 'Luke', 'Mike', 'Peter'}

# %%
s1.add("ab")

# %%
s1
# Out:
# {'Allen', 'Finn', 'Jack', 'Luke', 'Mike', 'Peter', 'ab'}

# %%
data=s1.copy()
data
# Out:
# {'Allen', 'Finn', 'Jack', 'Luke', 'Mike', 'Peter', 'ab'}

# %%
data.clear()

# %%
data
# Out:
# set()

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
def add_element(s):
    ele = input("Enter element to add: ")
    s.add(ele)
    print("Set after adding:", s)

def copy_set(s):
    backup = s.copy()
    print("Backup data:", backup)

def clear_set(s):
    s.clear()
    print("Empty set:", s)

def delete_element(s):
    l = list(s)
    print("Elements:", l)
    ind = int(input("Enter index value to remove element: "))
    if 0 <= ind < len(l):
        l.pop(ind)
        s = set(l)
        print("Set after deletion:", s)
    else:
        print("Invalid index.")

if __name__ == "__main__":
    s1 = {'Allen', 'Finn', 'Luke', 'Mike', 'Sean'}

    print("Options:")
    print("1. Add")
    print("2. Copy")
    print("3. Delete")
    print("4. Clear data")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        add_element(s1)
    elif choice == 2:
        copy_set(s1)
    elif choice == 3:
        delete_element(s1)
    elif choice == 4:
        clear_set(s1)
    else:
        print("Invalid option")
# Out:
# Options:
# 1. Add
# 2. Copy
# 3. Delete
# 4. Clear data
# Enter your choice: 1
# Enter element to add: 3
# Set after adding: {'3', 'Luke', 'Allen', 'Finn', 'Sean', 'Mike'}

# %%
data = {'3', 'Luke', 'Allen', 'Finn', 'Sean', 'Mike'}

# %%
inp = input("\nDo You Want To Remove Data With Error Or Error Free (Remove/Discard): ")
value = input("Enter Value To Remove: ")

if inp == "Remove":
    print("\nWith Error..")
    if value in data:
        data.remove(value)
        print("\nSuccessfully Removed.")
        print("\nUpdated Data Is:", data)
    else:
        print("\nValue not found in Data.")
elif inp == "Discard":
    print("\nThis Method Does Not Raise Error.")
    data.discard(value)
    print("\nSuccessfully Removed.")
    print("\nUpdated Data Is:", data)
else:
    print("\nInvalid Method. Please choose 'Remove' or 'Discard'.")
# Out:
# Do You Want To Remove Data With Error Or Error Free (Remove/Discard): Discard
# Enter Value To Remove: 3
#
# This Method Does Not Raise Error.
#
# Successfully Removed.
#
# Updated Data Is: {'Luke', 'Finn', 'Allen', 'Sean', 'Mike'}

# %%
a1 = {100,10,5,6}
b1 = {10,5}

# %%
b1.issubset(a1)
# Out:
# True

# %%
a1.issubset(b1)
# Out:
# False

# %%
a1.issuperset(b1)
# Out:
# True

# %%
b1.issuperset(a1)
# Out:
# False

# %%
def add_element(s):
    ele = input("Enter element to add: ")
    s.add(ele)
    print("Set after adding:", s)

def copy_set(s):
    backup = s.copy()
    print("Backup data:", backup)

def clear_set(s):
    s.clear()
    print("Empty set:", s)

def delete_element(s):
    l = list(s)
    print("Elements:", l)
    ind = int(input("Enter index value to remove element: "))
    if 0 <= ind < len(l):
        l.pop(ind)
        s = set(l)
        print("Set after deletion:", s)
    else:
        print("Invalid index.")

def union_set(s1, s2):
    union_result = s1.union(s2)
    print("Union of sets:", union_result)

def intersection_set(s1, s2):
    intersection_result = s1.intersection(s2)
    print("Intersection of sets:", intersection_result)

def difference_set(s1, s2):
    difference_result = s1.difference(s2)
    print("Difference of sets (s1 - s2):", difference_result)

def symmetric_difference_set(s1, s2):
    symmetric_difference_result = s1.symmetric_difference(s2)
    print("Symmetric Difference of sets:", symmetric_difference_result)

def difference_update_set(s1, s2):
    s1.difference_update(s2)
    print("Set after updating difference (s1 - s2):", s1)

def update_set(s1, s2):
    s1.update(s2)
    print("Set after updating with s2:", s1)

def is_subset(s1, s2):
    is_subset_result = s1.issubset(s2)
    print("Is s1 a subset of s2:", is_subset_result)

def is_superset(s1, s2):
    is_superset_result = s1.issuperset(s2)
    print("Is s1 a superset of s2:", is_superset_result)

if __name__ == "__main__":
    s1 = {'Allen', 'Finn', 'Luke', 'Mike', 'Sean'}
    s2 = {'Luke', 'Sean', 'Emily', 'Finn', 'Ella'}

    print("Options:")
    print("1. Add")
    print("2. Copy")
    print("3. Delete")
    print("4. Clear data")
    print("5. Union")
    print("6. Intersection")
    print("7. Difference")
    print("8. Symmetric Difference")
    print("9. Difference Update (s1 - s2)")
    print("10. Update (s1 + s2)")
    print("11. Is Subset")
    print("12. Is Superset")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        add_element(s1)
    elif choice == 2:
        copy_set(s1)
    elif choice == 3:
        delete_element(s1)
    elif choice == 4:
        clear_set(s1)
    elif choice == 5:
        union_set(s1, s2)
    elif choice == 6:
        intersection_set(s1, s2)
    elif choice == 7:
        difference_set(s1, s2)
    elif choice == 8:
        symmetric_difference_set(s1, s2)
    elif choice == 9:
        difference_update_set(s1, s2)
    elif choice == 10:
        update_set(s1, s2)
    elif choice == 11:
        is_subset(s1, s2)
    elif choice == 12:
        is_superset(s1, s2)
    else:
        print("Invalid option")
# Out:
# Options:
# 1. Add
# 2. Copy
# 3. Delete
# 4. Clear data
# 5. Union
# 6. Intersection
# 7. Difference
# 8. Symmetric Difference
# 9. Difference Update (s1 - s2)
# 10. Update (s1 + s2)
# 11. Is Subset
# 12. Is Superset
# Enter your choice: 11
# Is s1 a subset of s2: False

# %%
def remove_duplicates_from_file(file_path):
    try:
        with open(file_path, "r") as file:
            elements = file.read().split()

        unique_elements = set(elements)

        with open(file_path, "w") as file:
            file.write(" ".join(unique_elements))

        print("Duplicates removed and unique elements written back to the file.")

    except FileNotFoundError:
        print("File not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    file_path = "/content/emp"
    remove_duplicates_from_file(file_path)
# Out:
# File not found.

# %%
emp={"Name":"Jenny"}

# %%
key = input("Enter The Key :")
if key in emp:
    print("\nNow You Can Change The Value ..")
    emp[key] = input("\nEnter The New Value :")
    print("\nThe Updated Data Is :","\n")
    print(emp)
else:
    print()
    print(key,"Key Is Not Exist..")
# Out:
# Enter The Key :Salary
#
# Salary Key Is Not Exist..

# %%
inp = input("Do You Want To Make Empty Dictionary :")
if inp=="Yes":
    emp.clear()
    print("\nEmpty Dictionary Is :",emp)
else:
    print("\nOkay !!")
# Out:
# Do You Want To Make Empty Dictionary :Yes
#
# Empty Dictionary Is : {}

# %%
key = input("Enter The Key To Remove :")
if key in emp:
    print("\nNow You CAn Remove The Key.")
    emp.pop(key)
    print("\nThe Updated Data Is :",emp)
else:
    print("\nKey :",key,"Is Not Exist Here.")
# Out:
# Enter The Key To Remove :Name
#
# Key : Name Is Not Exist Here.

# %%
def login():

    users = {
        "user1": {
            "password": "password1",
            "name": "Jack",
            "age": 30,
            "email": "jack@gmail.com"
        },
        "user2": {
            "password": "password2",
            "name": "Jane",
            "age": 25,
            "email": "jane@gmail.com"
        },
        "user3": {
            "password": "password3",
            "name": "Mike",
            "age": 28,
            "email": "mike@gmail.com"
        }
    }

    username = input("Username: ")
    password = input("Password: ")


    if username in users and users[username]["password"] == password:
        print("Login successful!")

        print("Name:", users[username]["name"])
        print("Age:", users[username]["age"])
        print("Email:", users[username]["email"])
    else:
        print("Invalid username or password.")

if __name__ == "__main__":
    login()

# %%
def signup():

    users = {}
    username = input("Enter a new username: ")
    while username in users:
        print("Username already exists. Please choose another username.")
        username = input("Enter a new username: ")

    password = input("Enter a password: ")
    name = input("Enter your name: ")
    age = int(input("Enter your age: "))
    email = input("Enter your email address: ")


    users[username] = {
        "password": password,
        "name": name,
        "age": age,
        "email": email
    }

    print("Signup successful!")

def login(users):

    username = input("Username: ")
    password = input("Password: ")


    if username in users and users[username]["password"] == password:
        print("Login successful!\n\n")
        print("\t\t\t============ USER DETAILS :============ \n ")
        print("Name:", users[username]["name"])
        print("Age:", users[username]["age"])
        print("Email:", users[username]["email"])
    else:
        print("Invalid username or password.")
        forget_password(users, username)

def forget_password(users, username):
    if username not in users:
        print("Username does not exist.")
        return

    email_input = input("Enter your registered email address: ")
    if email_input == users[username]["email"]:
        new_password = input("Enter a new password: ")
        users[username]["password"] = new_password
        print("Password reset successful. You can now log in with your new password.")
    else:
        print("Email address does not match the registered email for this account.")

if __name__ == "__main__":
    users = {
        "jack_2": {
            "password": "pass123",
            "name": "Jack",
            "age": 30,
            "email": "jack@gmail.com"
        },
        "jane98": {
            "password": "password22",
            "name": "Jane",
            "age": 25,
            "email": "jane@gmail.com"
        },
        "mike002": {
            "password": "mike@143",
            "name": "Mike",
            "age": 28,
            "email": "mike@gmail.com"
        }
    }


    print("\t\t\t============ FACEBOOK ============ \n\n ")
    print("Options:")
    print("1. Signup")
    print("2. Login")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        signup()
    elif choice == 2:
        while True:
            login(users)
            choice = input("Do you want to forget password? (yes/no): ").lower()
            if choice == "yes":
                forget_password(users, username)
                break
            elif choice == "no":
                break
            else:
                print("Invalid choice. Please enter 'yes' or 'no'.")
    else:
        print("Invalid option.")
# Out:
# 			============ FACEBOOK ============
#
#
# Options:
# 1. Signup
# 2. Login
# Enter your choice: 2
# Username: mike002
# Password: mike@143
# Login successful!
#
#
# 			============ USER DETAILS :============
#
# Name: Mike
# Age: 28
# Email: mike@gmail.com
# Do you want to forget password? (yes/no): no
