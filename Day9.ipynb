# %%
name = 'ALLEN'

# %%
name[0]
# Out:
# 'A'

# %%
for k in name:
  print("Char is : ",k)
# Out:
# Char is :  A
# Char is :  L
# Char is :  L
# Char is :  E
# Char is :  N

# %%
a=0
stud = ["Mike","Luke","Jack","Peter","Finn"]
for name in stud:
    print(a,f" => Stud Name Is : {name}")

    a+=1
# Out:
# 0  => Stud Name Is : Mike
# 1  => Stud Name Is : Luke
# 2  => Stud Name Is : Jack
# 3  => Stud Name Is : Peter
# 4  => Stud Name Is : Finn

# %%
pip install simple_colors

# %%
import simple_colors as color
a = 0
for k in stud:
    if a%2==0:
        print(a,color.green(f" => Stud Is : {k}",'bold'))
    else:
        print(a,color.red(f" => Stud Is : {k}",'bold'))
    a+=1
# Out:
# 0  => Stud Is : Mike
# 1  => Stud Is : Luke
# 2  => Stud Is : Jack
# 3  => Stud Is : Peter
# 4  => Stud Is : Finn

# %%
msg = input("Enter Msg :")
print()
for k in msg:
    print(k)
# Out:
# Enter Msg :hello world
#
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
msg = input("Enter Msg :")
print()
for k in msg:
    print(k,end="")
# Out:
# Enter Msg :hello mike
#
# hello mike

# %%
import time

# %%
msg = input("Enter Msg :")
print()
for k in msg:
    print(k,end= " ")
    time.sleep(0.5)
# Out:
# Enter Msg :Hello Mike !
#
# H e l l o   M i k e   !

# %%
msg = input("Enter Msg :")
print()
for k in range(len(msg)):
    print(f"Index Num Is : {k}")
# Out:
# Enter Msg :Hello Mike !
#
# Index Num Is : 0
# Index Num Is : 1
# Index Num Is : 2
# Index Num Is : 3
# Index Num Is : 4
# Index Num Is : 5
# Index Num Is : 6
# Index Num Is : 7
# Index Num Is : 8
# Index Num Is : 9
# Index Num Is : 10
# Index Num Is : 11

# %%
msg = input("Enter Msg :")
print()
for k in range(len(msg)):
    if k%2==0:
        print(k,color.green(f" => Char Is : {msg[k]}",'bold'))
    elif msg[k]=="":
        msg = msg.replace(k,"😉")
        print(color.black(f" => Char Is : {msg[k]}",'bold'),end="")
    else:
        print(k,color.red(f" => Char Is : {msg[k]}",'bold'))
    time.sleep(0.5)
# Out:
# Enter Msg :Hello Mike !
#
# 0  => Char Is : H
# 1  => Char Is : e
# 2  => Char Is : l
# 3  => Char Is : l
# 4  => Char Is : o
# 5  => Char Is :
# 6  => Char Is : M
# 7  => Char Is : i
# 8  => Char Is : k
# 9  => Char Is : e
# 10  => Char Is :
# 11  => Char Is : !

# %%
msg = input("Enter Msg :")
print()
for k in range(len(msg)):
    if k%2==0:
        print(color.green(f"{msg[k]}",'bold'),end="")

    else:
        print(color.red(f"{msg[k]}",'bold'),end="")
    time.sleep(0.5)
# Out:
# Enter Msg :Hello Mike
#
# Hello Mike

# %%
msg = input("Enter Msg :")
print()
for k in range(len(msg)):
    if k%2==0:
        print(color.green(f"{msg[k]}",'bold'),end="")
    elif msg[k]==" ":
        msg = msg.replace(msg[k],"a")
        print(color.black(f"{msg[k]}",'bold'),end="")
    else:
        print(color.red(f"{msg[k]}",'bold'),end="")
    time.sleep(0.5)
# Out:
# Enter Msg :Hello Mike
#
# HelloaMike

# %%
def generate_char_data(start_index, end_index):
    char_data = []
    for index in range(start_index, end_index + 1):
        char_data.append(chr(index))
        str=""

    return (str.join(char_data))


start_index = 65
end_index = 90

result = generate_char_data(start_index, end_index)
print(result)
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
stud=['Mike', 'Luke', 'Jack', 'Peter', 'Finn', 'Nile', 'Allen', 'Jacob']
print("The original list is : ", data)
for a in range(len(stud)):
    if a%2 != 0:
        stud.remove(stud[a])
print("Updated list : ",stud)
# Out:
# The original list is :  ['Mike', 'Luke', 'Jack', 'Peter', 'Finn', 'Nile', 'Allen', 'Jacob']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-891529bbc28b> in <cell line: 3>()
#       3 for a in range(len(stud)):
#       4     if a%2 != 0:
# ----> 5         stud.remove(stud[a])
#       6 print("Updated list : ",stud)
#
# IndexError: list index out of range

# %% [markdown]
# The error `IndexError: list index out of range` occurs because we are modifying the list `stud` while iterating over it using a `for` loop with the `remove` method. When we remove an element from the list, its size decreases, and the index of the elements after the removed element is updated accordingly. This causes an index out of range error when the loop reaches the end of the list after some elements have been removed.
#
# Let's walk through what happens in each iteration of the loop:
#
# 1. Initial list: `['Mike', 'Luke', 'Jack', 'Peter', 'Finn', 'Nile', 'Allen', 'Jacob']`
# 2. `a = 0`: The element at index 0 is `'Mike'`, which stays in the list.
# 3. `a = 1`: The element at index 1 is `'Luke'`, and since `1 % 2` is not equal to 0, `'Luke'` is removed from the list. The list becomes `['Mike', 'Jack', 'Peter', 'Finn', 'Nile', 'Allen', 'Jacob']`.
# 4. `a = 2`: The element at index 2 is now `'Peter'`, which was previously at index 3. Since `'Luke'` was removed in the previous iteration, the elements are shifted, and `'Peter'` takes its place at index 2.
# 5. `a = 3`: The element at index 3 is now `'Finn'`, which was previously at index 4. Again, due to the shifting, `'Finn'` takes its place at index 3.
# 6. `a = 4`: The element at index 4 is now `'Nile'`, which was previously at index 5. The elements keep shifting, causing `'Nile'` to take its place at index 4.
#
# At this point, the loop has already gone beyond the length of the updated list, and it tries to access an element at an index that doesn't exist, resulting in the `IndexError`.
#
# To avoid this error, we should not modify the list while iterating over it. Instead, we can create a new list containing the elements we want to keep. This way, the original list remains unchanged, and we get the desired result without encountering an `IndexError`.

# %%
data = input("Enter Message : ")
chara = input("Enter character to be counted : ")
count = 0

for i in data:
	if i == chara:
		count = count + 1


print(f"Count of {chara} in {data} is : ",count)
# Out:
# Enter Message : Hello
# Enter character to be counted : l
# Count of l in Hello is :  2

# %%
msg=input("enter msg: ")
ch=input("Enter the charcter: ")
count=msg.count(ch)
print(f"{ch} is {count} times in msg")
# Out:
# enter msg: f
# Enter the charcter: d
# d is 0 times in msg

# %%
name = ["Sean","Jack","Luke","Mike","Finn"]
age = [15,16,15,16,10]
name = ["Sean", "Jack", "Luke", "Mike", "Finn"]
age = [15, 16, 15, 16, 10]


new_data = zip(name, age)

for name, age in new_data:
    print(f"{name} is {age} years old.")
# Out:
# Sean is 15 years old.
# Jack is 16 years old.
# Luke is 15 years old.
# Mike is 16 years old.
# Finn is 10 years old.

# %%
name = ["Sean", "Jack", "Luke", "Mike", "Finn"]
age = [15, 16, 15, 16, 10]
data = {}

i = 0
for key in name:
    data[key] = age[i]
    i += 1

print(data)
# Out:
# {'Sean': 15, 'Jack': 16, 'Luke': 15, 'Mike': 16, 'Finn': 10}

# %% [markdown]
# ==> Make Statements From 65 To 122 Number According To User.
#
# ==> Find Special Char , Number , Char ,Bool And Emoji From Given Data.
#
#     Data = "Sean@gmail.comMike Is 😀.Password Is 25166@##.Okay!!100True"
#
# ==> Encode A Msg Using Input Function With Options :
#
#     Decode By : Key And Passowrd
#
# ==> Make A Program Using While And For Loop.
#
#
# ==> Make A Program To Find Any Word From HTML And Text File.
#
# ⇒ str1 = "abnjeropsuilvsdabnjer"
# Find The Unique Values From Given String.
# Append The Single Char In A List.
#  Make Two Words.
#  Find The Vowels From Given String.
#  Find The Consonant From Given String.
#
# ⇒ Marks = {"Sean":560,"Mike":520,"Jenny":595,"Luke":500,"Finn":555}
# Take A Input And Get The Marks of Stud(Key) if Exist.
# Get The Marks With Percentage , Here Total Marks Is 600.
#  Find The Max And Min Percentage.
#  Find The Mean And Median.

# %%
data = "Sean@gmail.comMike Is 😀.Password Is 25166@##.Okay!!100True"

special_char_count = 0
number_count = 0
char_count = 0
bool_count = 0
emoji_count = 0


def is_emoji(char):
    emoji_range = (0x1F600, 0x1F64F)
    return ord(char) in range(*emoji_range)


for char in data:
    if char.isalnum():
        if char.isalpha():
            char_count += 1
        else:
            number_count += 1
    elif char in "!@#$%^&*()_-+=<>?/,.:;{}[]|\\":
        special_char_count += 1
    elif char in ("True", "False"):
        bool_count += 1
    elif is_emoji(char):
        emoji_count += 1

print("Special Characters:", special_char_count)
print("Numbers:", number_count)
print("Characters:", char_count)
print("Booleans:", bool_count)
print("Emojis:", emoji_count)
# Out:
# Special Characters: 9
# Numbers: 8
# Characters: 36
# Booleans: 0
# Emojis: 1

# %%
def even_numbers_while(limit):
    total = 0
    current_number = 2
    while current_number <= limit:
        total += current_number
        current_number += 2
    return total

def even_numbers_for(limit):
    total = 0
    for number in range(2, limit + 1, 2):
        total += number
    return total

limit = int(input("Enter the upper limit: "))


result_while = even_numbers_while(limit)
print("Sum of even numbers using while loop:", result_while)


result_for = even_numbers_for(limit)
print("Sum of even numbers using for loop:", result_for)
# Out:
# Enter the upper limit: 10
# Sum of even numbers using while loop: 30
# Sum of even numbers using for loop: 30

# %%
def msg():
    print("Now We Are Learning Function.")

# %%
msg()
# Out:
# Now We Are Learning Function.

# %%
def gen_data():
    ques = input("Do You Want To Generate Data :")
    if ques =="Yes":
        name = input("\nEnter Name :")
        age =  int(input("\nEnter Age :"))
        city = input("\nEnter City :")
        contact = input("\nEnter Contact :")
        print(f'''
                                       INFORMATION

                  1. Stud Name Is : {name}
                  2. Stud Age  Is : {age}
                  3. Stud City Is : {city}
                  4. Stud Num  Is : {contact}
''')
    else:
        print("\nPls Exit..")

# %%
gen_data()
# Out:
# Do You Want To Generate Data :yes
#
# Pls Exit..

# %%
def evenodd():
    num = int(input("Enter A Num :"))
    if num%2==0:
        print("\nEven Num Is :",num)
    else:
        print("\nOdd Num Is :",num)

# %%
evenodd()
# Out:
# Enter A Num :5
#
# Odd Num Is : 5

# %%
def evenodd():
    num = int(input("Enter A Num :"))
    if num%2==0:
        print(Fore.GREEN+"\nEven Num Is :" +str(num))
    else:
        print(Fore.RED+"\nOdd Num Is :"+str(num))

# %%
evenodd()
# Out:
# Enter A Num :6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-9c7955ec9c30> in <cell line: 1>()
# ----> 1 evenodd()
#
# <ipython-input-72-fcec098b4fa1> in evenodd()
#       2     num = int(input("Enter A Num :"))
#       3     if num%2==0:
# ----> 4         print(Fore.GREEN+"\nEven Num Is :" +str(num))
#       5     else:
#       6         print(Fore.RED+"\nOdd Num Is :"+str(num))
#
# NameError: name 'Fore' is not defined

# %%
def evenodd():
    num = int(input("Enter A Num :"))
    if num%2==0:
        print(Fore.GREEN+Back.BLACK+"\nEven Num Is :" +str(num))
    else:
        print(Fore.RED+Back.BLACK+"\nOdd Num Is :"+str(num))

# %%
def cal():
    num1 = int(input("Enter 1st Num :"))
    num2 = int(input("\nEnter 2nd Num :"))
    add = num1+num2
    sub = num1-num2
    mul = num1*num2
    div = num1/num2
    opt = input("\nSelect Option :")
    if opt=="Addition":
        print("\nAdd Is :",add)
    elif opt=="Subtraction":
        print("\nSub Is :",sub)
    elif opt == "Multiplication":
        print("\nMul Is :",mul)
    elif opt == "Division":
        print("\nDiv Is :",div)
    else:
        print("\nNo Option Is Here.")

# %%
cal()
# Out:
# Enter 1st Num :10
#
# Enter 2nd Num :34
#
# Select Option :Division
#
# Div Is : 0.29411764705882354
