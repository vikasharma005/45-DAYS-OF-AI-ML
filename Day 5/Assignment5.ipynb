# %% [markdown]
# # Assignment 5

# %% [markdown]
# # Q1 Make A Bill Generator Application Using Tkinter With Colors.

# %%
from tkinter import*
import tkinter.messagebox
root1 = Tk()
root1.geometry("420x220+0+0")
root1.title("Login Page")

name_inp = StringVar()
password_inp = StringVar()



def enter():
	if name_inp.get() == "admin" and password_inp.get() == "1234":
		root1.destroy()
		import question
	else:
		tkinter.messagebox.showinfo('Error','Authentication Failed')
		name_inp.set("")
		password_inp.set("")

def destroy():
	root1.destroy()


label = Label(root1, font = ('arial',50,'bold'), text ="Login", fg = "steel blue", bd = 10, anchor = 'w')
label.grid(row = 0)


label1 = Label(root1, text="Username")
label2 = Label(root1, font =('slant',10,'bold'),text="Pin")

entry1 = Entry(root1, textvariable = name_inp)
entry2 = Entry(root1, textvariable = password_inp)

label1.grid(row=1, sticky=E)
label2.grid(row=2,sticky=E)
entry1.grid(row=1,column=1)
entry2.grid(row=2,column=1)

enter_btn = Button(root1, text="Enter", command= enter)
enter_btn.grid(row=3, column=1)

exit_btn = Button(root1, padx= 1, text="Exit", command= destroy)
exit_btn.grid(row=3,column=2)

root1.mainloop()

# %%
from tkinter import*
import tkinter.messagebox


left1 = Tk()
left1.geometry("1600x800+0+0")
left1.title("Change Price")

label4 = Label(left1, font = ('arial',50,'bold'), text ="Change Price", fg = "steel blue", bd = 10, anchor = 'w')
label4.grid(row = 0)


fries_inp_p = StringVar()
Sandwich_inp_p = StringVar()
burger_inp_p = StringVar()
drinks_inp_p = StringVar()
Pasta_inp_p = StringVar()
Tacos_inp_p = StringVar()

def update():
	f = open('value.txt','r')
	line = f.readlines()
	fries_p = float(line[0])
	Sandwich_p = float(line[1])
	burger_p = float(line[2])
	drinks_p = float(line[3])
	Pasta_p = float(line[4])
	Tacos_p = float(line[5])
	f.close()

	f2 = open('value.txt','w')
	try:
		CoF1 = float(fries_inp_p.get())
	except Exception as e:
		if fries_inp_p.get() != "":
			tkinter.messagebox.showinfo('Error','Incorrect Input')
		fries_inp_p.set("")
		f2.write(str(fries_p)+"\n")
	else:
		f2.write(str(CoF1)+"\n")

	try:
		CoS1 = float(Sandwich_inp_p.get())
	except Exception as e:
		if Sandwich_inp_p.get() != "":
			tkinter.messagebox.showinfo('Error','Incorrect Input')
		Sandwich_inp_p.set("")
		f2.write(str(Sandwich_p)+"\n")
	else:
		f2.write(str(CoS1)+"\n")

	try:
		CoB1 = float(burger_inp_p.get())
	except Exception as e:
		if burger_inp_p.get() != "":
			tkinter.messagebox.showinfo('Error','Incorrect Input')
		burger_inp_p.set("")
		f2.write(str(burger_p)+"\n")
	else:
		f2.write(str(CoB1)+"\n")

	try:
		CoD1 = float(drinks_inp_p.get())
	except Exception as e:
		if drinks_inp_p.get() != "":
			tkinter.messagebox.showinfo('Error','Incorrect Input')
		drinks_inp_p.set("")
		f2.write(str(drinks_p)+"\n")
	else:
		f2.write(str(CoD1)+"\n")

	try:
		CoP1 = float(Pasta_inp_p.get())
	except Exception as e:
		if Pasta_inp_p.get() != "":
			tkinter.messagebox.showinfo('Error','Incorrect Input')
		Pasta_inp_p.set("")
		f2.write(str(Pasta_p)+"\n")
	else:
		f2.write(str(CoP1)+"\n")

	try:
		CoC1 = float(Tacos_inp_p.get())
	except Exception as e:
		if Tacos_inp_p.get() != "":
			tkinter.messagebox.showinfo('Error','Incorrect Input')
		Tacos_inp_p.set("")
		f2.write(str(Tacos_p))
	else:
		f2.write(str(CoC1))

	#f.write(str(Sandwich_p) +"\n"+ str(Pasta_p) +"\n"+ str(Tacos_p) +"\n"+ str(fries_p) +"\n"+ str(burger_p) +"\n"+ str(drinks_p))

	tkinter.messagebox.showinfo('Update Box','Successfully Updated')
	f2.close()

def reset1():
	fries_inp_p.set("")
	Sandwich_inp_p.set("")
	burger_inp_p.set("")
	drinks_inp_p.set("")
	Pasta_inp_p.set("")
	Tacos_inp_p.set("")

def qexit1():
	left1.destroy()

def printfn():
	f3 = open('value.txt','r')
	liness = f3.readlines()
	fries_p = float(liness[0])
	Sandwich_p = float(liness[1])
	burger_p = float(liness[2])
	drinks_p = float(liness[3])
	Pasta_p = float(liness[4])
	Tacos_p = float(liness[5])
	print("fry "+str(fries_p))
	print("Sandwich "+str(Sandwich_p))
	print("chi tikka "+str(Tacos_p))
	print("Pasta "+str(Pasta_p))
	print("burger "+str(burger_p))
	print("drinks "+str(drinks_p))
	f3.close()

def backfn():
	left1.destroy()
	import question


fries = Label(left1, font=('arial',16,'bold'),text = "Fries", bd = 16, anchor = 'w' )
fries.grid(row=1,column=0,sticky = E)
txt_fries = Entry(left1,font=('arial',16,'bold'), textvariable=fries_inp_p, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_fries.grid(row=1,column=1)

Sandwich = Label(left1, font=('arial',16,'bold'),text = "Sandwich", bd = 16, anchor = 'w' )
Sandwich.grid(row=2,column=0,sticky = E)
txt_Sandwich = Entry(left1,font=('arial',16,'bold'), textvariable=Sandwich_inp_p, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_Sandwich.grid(row=2,column=1)


burger = Label(left1, font=('arial',16,'bold'),text = "Burger", bd = 16, anchor = 'w' )
burger.grid(row=3,column=0,sticky = E)
txt_burger = Entry(left1,font=('arial',16,'bold'), textvariable=burger_inp_p, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_burger.grid(row=3,column=1)

drinks = Label(left1, font=('arial',16,'bold'),text = "Drinks", bd = 16, anchor = 'w' )
drinks.grid(row=4,column=0,sticky = E)
txt_drinks = Entry(left1,font=('arial',16,'bold'), textvariable=drinks_inp_p, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_drinks.grid(row=4,column=1)

Pasta = Label(left1, font=('arial',16,'bold'),text = "Pasta", bd = 16, anchor = 'w' )
Pasta.grid(row=5,column=0,sticky = E)
txt_Pasta = Entry(left1,font=('arial',16,'bold'), textvariable=Pasta_inp_p, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_Pasta.grid(row=5,column=1)

Tacos = Label(left1, font=('arial',16,'bold'),text = "Tacos", bd = 16, anchor = 'w' )
Tacos.grid(row=6,column=0,sticky = E)
txt_Tacos = Entry(left1,font=('arial',16,'bold'), textvariable=Tacos_inp_p, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_Tacos.grid(row=6,column=1)


btn_update = Button(left1, padx= 16, pady= 8, bd= 16, fg= "black", font=('arial',16,'bold'), width=10, text= "Update", bg= "powder blue",command = update)
btn_update.grid(row=7, column= 1)

btn_reset1 = Button(left1, padx= 16, pady= 8, bd= 16, fg= "black", font=('arial',16,'bold'), width=10, text= "Reset", bg= "powder blue",command = reset1)
btn_reset1.grid(row=7, column= 2)

btn_exit1 = Button(left1, padx= 16, pady= 8, bd= 16, fg= "black", font=('arial',16,'bold'), width=10, text= "Exit", bg= "powder blue",command = qexit1)
btn_exit1.grid(row=7, column= 3)

btn_print = Button(left1, padx= 16, pady= 8, bd= 16, fg= "black", font=('arial',16,'bold'), width=10, text= "print", bg= "powder blue",command = printfn)
btn_print.grid(row=7, column= 4)

btn_back = Button(left1, padx= 16, pady= 8, bd= 16, fg= "black", font=('arial',16,'bold'), width=10, text= "Back", bg= "powder blue",command = backfn)
btn_back.grid(row=8, column= 3)



left1.mainloop()

# %%
from tkinter import*

newroot = Tk()

newroot.geometry("200x120+0+0")
newroot.title("Menu")



def enter1():
	newroot.destroy()
	import restaurant_management_system


def enter2():
	newroot.destroy()
	import price


label11 = Label(newroot, text="Bill")
label11.grid(row=1, sticky=E)

press_btn = Button(newroot, text="Press Here", command= enter1)
press_btn.grid(row=1, column=1)

label21 = Label(newroot, text="Change Price")
label21.grid(row=2,sticky=E)

press1_btn = Button(newroot, text="Press Here", command= enter2)
press1_btn.grid(row=2, column=1)

newroot.mainloop()

# %%
from tkinter import*
import tkinter.messagebox
import time
import random

operator = ""
#### creating window and its geometry ######

root = Tk()
root.geometry("1600x800+0+0")
root.title("Restaurant Bill Calculator")


#### creating Frame ######

top = Frame(root, width = 1600, height = 50, relief = SUNKEN)
top.pack(side = TOP)

left = Frame(root, width = 800, height = 700, relief = SUNKEN)
left.pack(side = LEFT)

right = Frame(root, width = 300, height = 700, relief = SUNKEN)
right.pack(side = RIGHT)


##### creating label of title and time ###

label_info = Label(top, font = ('arial',50,'bold'), text ="Bill Calculator", fg = "steel blue", bd = 10, anchor = 'w')
label_info.grid(row = 0, column = 0)

local_time = time.asctime(time.localtime(time.time()))

label_info = Label(top, font = ('arial',20,'bold'), text = local_time, fg = "steel blue", bd = 10, anchor = 'w')
label_info.grid(row = 1, column = 0)


######## creating calculator #######

txt_inp = StringVar()

def btn_click(number):
	global operator
	operator = operator+ str(number)
	txt_inp.set(operator)

def fun_clear():
	global operator
	operator = ""
	txt_inp.set(operator)

def calculate():
	global operator
	try:
		sumup = str(eval(operator))
	except Exception as e:
		tkinter.messagebox.showinfo('Error','Incorrect Input')
		sumup = 0
		fun_clear()
	txt_inp.set(sumup)
	operator = ""




txt = Entry(right, font = ('arial',20,'bold'), textvariable = txt_inp, bd = 30, insertwidth = 4, bg = "powderblue", justify = 'right')
txt.grid(columnspan = 4)


#=========first row button=========

btn7 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="7", bg="powder blue", command=lambda: btn_click(7))
btn7.grid(row= 2, column= 0)

btn8 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="8", bg="powder blue", command=lambda: btn_click(8))
btn8.grid(row= 2, column= 1)

btn9 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="9", bg="powder blue", command=lambda: btn_click(9))
btn9.grid(row= 2, column= 2)

plus = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="+", bg="powder blue", command=lambda: btn_click("+"))
plus.grid(row= 2, column= 3)


#=========second row button=========

btn4 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="4", bg="powder blue", command=lambda: btn_click(4))
btn4.grid(row= 3, column= 0)

btn5 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="5", bg="powder blue", command=lambda: btn_click(5))
btn5.grid(row= 3, column= 1)

btn6 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="6", bg="powder blue", command=lambda: btn_click(6))
btn6.grid(row= 3, column= 2)

minus = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="-", bg="powder blue", command=lambda: btn_click("-"))
minus.grid(row= 3, column= 3)


#=========third row button=========


btn1 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="1", bg="powder blue", command=lambda: btn_click(1))
btn1.grid(row= 4, column= 0)

btn2 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="2", bg="powder blue", command=lambda: btn_click(2))
btn2.grid(row= 4, column= 1)

btn3 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="3", bg="powder blue", command=lambda: btn_click(3))
btn3.grid(row= 4, column= 2)

multiply = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="*", bg="powder blue", command=lambda: btn_click("*"))
multiply.grid(row= 4, column= 3)


#=========fourth row button=========

btn0 = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="0", bg="powder blue", command=lambda: btn_click(0))
btn0.grid(row= 5, column= 0)

btn_clear = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="C", bg="powder blue",command=fun_clear)
btn_clear.grid(row= 5, column= 1)

btn_equal = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="=", bg="powder blue",command= calculate)
btn_equal.grid(row= 5, column= 2)

division = Button(right, padx= 16, pady=16, bd= 8, fg= "black", font= ('arial',20,'bold'), text="/", bg="powder blue", command=lambda: btn_click("/"))
division.grid(row= 5, column= 3)


###########now on left frame  enter menu ####################################################################

rand = StringVar()
fries_inp = StringVar()
Sandwich_inp = StringVar()
burger_inp = StringVar()
drinks_inp = StringVar()
total_inp = StringVar()
subtotal_inp = StringVar()
services_inp = StringVar()
tax_inp = StringVar()
cost_inp = StringVar()
Pasta_inp = StringVar()
Tacos_inp = StringVar()

def ref():

	f1 = open('value.txt','r')
	line = f1.readlines()
	fries_p = float(line[0])
	Sandwich_p = float(line[1])
	burger_p = float(line[2])
	drinks_p = float(line[3])
	Pasta_p = float(line[4])
	Tacos_p = float(line[5])
	f1.close()

	x = random.randint(23133,33344)
	random_ref = str(x)
	rand.set(random_ref)
	try:
		if fries_inp.get() == "":
			CoF = 0
		else:
			CoF = float(fries_inp.get())*fries_p
	except Exception as e:
		tkinter.messagebox.showinfo('Error','Incorrect Input')
		fries_inp.set("")

	try:
		if Sandwich_inp.get() == "":
			CoS = 0
		else:
			CoS = float(Sandwich_inp.get())*Sandwich_p
	except Exception as e:
		tkinter.messagebox.showinfo('Error','Incorrect Input')
		Sandwich_inp.set("")

	try:
		if burger_inp.get() == "":
			CoB = 0
		else:
			CoB = float(burger_inp.get())*burger_p
	except Exception as e:
		tkinter.messagebox.showinfo('Error','Incorrect Input')
		burger_inp.set("")

	try:
		if drinks_inp.get() == "":
			CoD = 0
		else:
			CoD = float(drinks_inp.get())*drinks_p
	except Exception as e:
		tkinter.messagebox.showinfo('Error','Incorrect Input')
		drinks_inp.set("")

	try:
		if Pasta_inp.get() == "":
			CoP = 0
		else:
			CoP = float(Pasta_inp.get())*Pasta_p
	except Exception as e:
		tkinter.messagebox.showinfo('Error','Incorrect Input')
		Pasta_inp.set("")

	try:
		if Tacos_inp.get() == "":
			CoC = 0
		else:
			CoC = float(Tacos_inp.get())*Tacos_p
	except Exception as e:
		tkinter.messagebox.showinfo('Error','Incorrect Input')
		Tacos_inp.set("")

	CostOfMeal = (CoF+CoS+CoB+CoD+CoP+CoC)

	PayTax = (CostOfMeal)*0.18
	ServiceCharge = (CostOfMeal)*0.05
	totalTax = PayTax + ServiceCharge
	totalCost = (CostOfMeal + PayTax + ServiceCharge)

	services_inp.set(str('%.2f' % (ServiceCharge)))
	tax_inp.set(str('%.2f' % (PayTax)))
	subtotal_inp.set(str('%.2f' % (CostOfMeal)))
	total_inp.set(str('%.2f' % (totalCost)))
	cost_inp.set(str('%.2f' % (totalTax)))



def bck():
	root.destroy()
	import question



def qexit():
	root.destroy()

def reset():
	rand.set("")
	fries_inp.set("")
	Sandwich_inp.set("")
	burger_inp.set("")
	drinks_inp.set("")
	total_inp.set("")
	subtotal_inp.set("")
	services_inp.set("")
	tax_inp.set("")
	cost_inp.set("")
	Pasta_inp.set("")
	Tacos_inp.set("")




customer_number = Label(left, font=('arial',16,'bold'),text = "Reference Id", bd = 16, anchor = 'w')
customer_number.grid(row=0,column=0,sticky = E)
txt_customer = Entry(left,font=('arial',16,'bold'), textvariable=rand, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_customer.grid(row=0,column=1)

fries = Label(left, font=('arial',16,'bold'),text = "Fries", bd = 16, anchor = 'w' )
fries.grid(row=1,column=0,sticky = E)
txt_fries = Entry(left,font=('arial',16,'bold'), textvariable=fries_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_fries.grid(row=1,column=1)

Sandwich = Label(left, font=('arial',16,'bold'),text = "Sandwich", bd = 16, anchor = 'w' )
Sandwich.grid(row=2,column=0,sticky = E)
txt_Sandwich = Entry(left,font=('arial',16,'bold'), textvariable=Sandwich_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_Sandwich.grid(row=2,column=1)


burger = Label(left, font=('arial',16,'bold'),text = "Burger", bd = 16, anchor = 'w' )
burger.grid(row=3,column=0,sticky = E)
txt_burger = Entry(left,font=('arial',16,'bold'), textvariable=burger_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_burger.grid(row=3,column=1)

drinks = Label(left, font=('arial',16,'bold'),text = "Drinks", bd = 16, anchor = 'w' )
drinks.grid(row=4,column=0,sticky = E)
txt_drinks = Entry(left,font=('arial',16,'bold'), textvariable=drinks_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_drinks.grid(row=4,column=1)

Pasta = Label(left, font=('arial',16,'bold'),text = "Pasta", bd = 16, anchor = 'w' )
Pasta.grid(row=5,column=0,sticky = E)
txt_Pasta = Entry(left,font=('arial',16,'bold'), textvariable=Pasta_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_Pasta.grid(row=5,column=1)

Tacos = Label(left, font=('arial',16,'bold'),text = "Tacos", bd = 16, anchor = 'w' )
Tacos.grid(row=0,column=2,sticky = E)
txt_Tacos = Entry(left,font=('arial',16,'bold'), textvariable=Tacos_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_Tacos.grid(row=0,column=3)

subtotal = Label(left, font=('arial',16,'bold'),text = "Cost of Meal", bd = 16, anchor = 'w' )
subtotal.grid(row=1,column=2,sticky = E)
txt_subtotal = Entry(left,font=('arial',16,'bold'), textvariable=subtotal_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_subtotal.grid(row=1,column=3)

services = Label(left, font=('arial',16,'bold'),text = "Service Charge", bd = 16, anchor = 'w' )
services.grid(row=2,column=2,sticky = E)
txt_services = Entry(left,font=('arial',16,'bold'), textvariable=services_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_services.grid(row=2,column=3)

tax = Label(left, font=('arial',16,'bold'),text = "GST", bd = 16, anchor = 'w' )
tax.grid(row=3,column=2,sticky = E)
txt_tax = Entry(left,font=('arial',16,'bold'), textvariable=tax_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_tax.grid(row=3,column=3)

cost = Label(left, font=('arial',16,'bold'),text = "Total Tax", bd = 16, anchor = 'w' )
cost.grid(row=4,column=2,sticky = E)
txt_cost = Entry(left,font=('arial',16,'bold'), textvariable=cost_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_cost.grid(row=4,column=3)

total = Label(left, font=('arial',16,'bold'),text = "Total Cost", bd = 16, anchor = 'w' )
total.grid(row=5,column=2,sticky = E)
txt_total = Entry(left,font=('arial',16,'bold'), textvariable=total_inp, bd=10, insertwidth =4,bg = "powder blue", justify ='right')
txt_total.grid(row=5,column=3)


### right Frame Button ###########

btn_total = Button(left, padx= 16, pady= 8, bd= 16, fg= "black", font=('arial',16,'bold'), width=10, text= "Total", bg= "powder blue",command = ref)
btn_total.grid(row=7, column= 1)

btn_reset = Button(left, padx= 16, pady= 8, bd= 16, fg= "black", font=('arial',16,'bold'), width=10, text= "Reset", bg= "powder blue",command = reset)
btn_reset.grid(row=7, column= 2)

btn_exit = Button(left, padx= 16, pady= 8, bd= 16, fg= "black", font=('arial',16,'bold'), width=10, text= "Exit", bg= "powder blue",command = qexit)
btn_exit.grid(row=7, column= 3)

btn_bck = Button(left, padx= 16, pady= 8, bd= 16, fg= "black", font=('arial',16,'bold'), width=10, text= "Back", bg= "powder blue",command = bck)
btn_bck.grid(row=8, column= 2)




root.mainloop()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Q2 Make A Program About The Operators Using Input Function.

# %%
def arithmetic_operator():
    num1 = float(input("Enter the first number: "))
    num2 = float(input("Enter the second number: "))

    print(f"\n\nAddition: {num1} + {num2} = {num1 + num2}")
    print(f"\nSubtraction: {num1} - {num2} = {num1 - num2}")
    print(f"\nMultiplication: {num1} * {num2} = {num1 * num2}")
    print(f"\nDivision: {num1} / {num2} = {num1 / num2}")
    print(f"\nFloor Division: {num1} // {num2} = {num1 // num2}")
    print(f"\nModulus: {num1} % {num2} = {num1 % num2}")
    print(f"\nExponentiation: {num1} ** {num2} = {num1 ** num2}")


def comparison_operator():
    num1 = float(input("Enter the first number: "))
    num2 = float(input("Enter the second number: "))

    print(f"\n\n{num1} == {num2}: {num1 == num2}")
    print(f"\n{num1} != {num2}: {num1 != num2}")
    print(f"\n{num1} > {num2}: {num1 > num2}")
    print(f"\n{num1} < {num2}: {num1 < num2}")
    print(f"\n{num1} >= {num2}: {num1 >= num2}")
    print(f"\n{num1} <= {num2}: {num1 <= num2}")


def logical_operator():
    bool1 = bool(input("Enter the first boolean value (True/False): "))
    bool2 = bool(input("Enter the second boolean value (True/False): "))

    print(f"\n\nLogical AND: {bool1} and {bool2} is {bool1 and bool2}")
    print(f"\nLogical OR: {bool1} or {bool2} is {bool1 or bool2}")
    print(f"\nLogical NOT: not {bool1} is {not bool1}")


def assignment_operator():
    num = float(input("Enter a number: "))
    print(f"\n\nNumber before assignment: {num}\n")

    # Using assignment operators
    num += 5
    print(f"\nNumber after 'num += 5': {num}")

    num -= 2
    print(f"\nNumber after 'num -= 2': {num}")

    num *= 3
    print(f"\nNumber after 'num *= 3': {num}")

    num /= 2
    print(f"\nNumber after 'num /= 2': {num}")

    num %= 4
    print(f"\nNumber after 'num %= 4': {num}")

    num **= 2
    print(f"\nNumber after 'num **= 2': {num}")

    num //= 3
    print(f"\nNumber after 'num //= 3': {num}")


def identity_operator():
    x = [1, 2, 3]
    y = [1, 2, 3]
    z = x

    print(f"\nx is y: {x is y}")
    print(f"\nx is z: {x is z}")
    print(f"\nx is not y: {x is not y}")
    print(f"\nx is not z: {x is not z}")


def membership_operator():
    nums = [1, 2, 3, 4, 5]

    num = int(input("Enter a number to check its membership: "))
    print(f"\n\n{num} in nums: {num in nums}")
    print(f"\n{num} not in nums: {num not in nums}")


def bitwise_operator():
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))

    print(f"\n\nBitwise AND: {num1} & {num2} = {num1 & num2}")
    print(f"\nBitwise OR: {num1} | {num2} = {num1 | num2}")
    print(f"\nBitwise XOR: {num1} ^ {num2} = {num1 ^ num2}")
    print(f"\nBitwise NOT: ~{num1} = {~num1}")
    print(f"\nBitwise Left Shift: {num1} << {num2} = {num1 << num2}")
    print(f"\nBitwise Right Shift: {num1} >> {num2} = {num1 >> num2}")


def main():
    print("\nChoose the type of operator you want to explore:\n")
    print("1. Arithmetic Operator")
    print("2. Comparison Operator")
    print("3. Logical Operator")
    print("4. Assignment Operator")
    print("5. Identity Operator")
    print("6. Membership Operator")
    print("7. Bitwise Operator")

    choice = int(input("\nEnter your choice (1-7): "))

    if choice == 1:
        arithmetic_operator()
    elif choice == 2:
        comparison_operator()
    elif choice == 3:
        logical_operator()
    elif choice == 4:
        assignment_operator()
    elif choice == 5:
        identity_operator()
    elif choice == 6:
        membership_operator()
    elif choice == 7:
        bitwise_operator()
    else:
        print("\nInvalid choice! Please choose a number from 1 to 7.")


if __name__ == "__main__":
    main()
# Out:
# Choose the type of operator you want to explore:
#
# 1. Arithmetic Operator
# 2. Comparison Operator
# 3. Logical Operator
# 4. Assignment Operator
# 5. Identity Operator
# 6. Membership Operator
# 7. Bitwise Operator
#
# Enter your choice (1-7): 7
# Enter the first number: 19
# Enter the second number: 90
#
#
# Bitwise AND: 19 & 90 = 18
#
# Bitwise OR: 19 | 90 = 91
#
# Bitwise XOR: 19 ^ 90 = 73
#
# Bitwise NOT: ~19 = -20
#
# Bitwise Left Shift: 19 << 90 = 23520860746422225223083360256
#
# Bitwise Right Shift: 19 >> 90 = 0

# %% [markdown]
# # **Explaination :**
#
# 1. The program starts by defining functions for each category of operators. These functions are responsible for taking user input and demonstrating the operations related to that category of operators.
#
# 2. The `main()` function acts as the main entry point of the program. It presents a menu to the user and asks them to choose the type of operator they want to explore.
#
# 3. After the user enters their choice (a number from 1 to 7), the program uses `if-elif-else` statements to call the corresponding function based on the user's choice.
#
# 4. Let's look at each function in detail:
#
#    a. `arithmetic_operator()`: This function takes two numerical inputs from the user and demonstrates various arithmetic operations such as addition, subtraction, multiplication, division, floor division, modulus, and exponentiation. It performs these operations using the given inputs and prints the results.
#
#    b. `comparison_operator()`: This function takes two numerical inputs from the user and demonstrates various comparison operations such as equal to, not equal to, greater than, less than, greater than or equal to, and less than or equal to. It compares the given inputs and prints the comparison results.
#
#    c. `logical_operator()`: This function takes two boolean inputs (True or False) from the user and demonstrates logical operations such as logical AND, logical OR, and logical NOT. It applies these logical operations to the given inputs and prints the results.
#
#    d. `assignment_operator()`: This function takes a numerical input from the user and demonstrates various assignment operations. It uses compound assignment operators (e.g., +=, -=, *=, /=, %=, **=, //=) to modify the given input and prints the updated value after each operation.
#
#    e. `identity_operator()`: This function demonstrates identity operations `is` and `is not`. It creates three lists, compares their identities, and prints the results to show whether the variables refer to the same object or not.
#
#    f. `membership_operator()`: This function takes a numerical input from the user and demonstrates membership operations `in` and `not in`. It checks if the input number is present in a predefined list and prints the result.
#
#    g. `bitwise_operator()`: This function takes two numerical inputs from the user and demonstrates various bitwise operations such as bitwise AND, bitwise OR, bitwise XOR, bitwise NOT, bitwise left shift, and bitwise right shift. It applies these operations to the given inputs and prints the results.
#
# 5. The `main()` function is called at the end of the program using `if __name__ == "__main__": main()`. This ensures that the `main()` function is executed when the program is run.
#
# 6. The program also handles invalid user choices by displaying an error message when the user enters a number other than 1 to 7.

# %% [markdown]
# # Q3 Make A GST Calculator With Colors.

# %%
def calculate_gst(cost, gst_rate):
    gst_amount = (cost * gst_rate) / 100
    total_cost = cost + gst_amount
    return gst_amount, total_cost

if __name__ == "__main__":
    try:
        cost = float(input("Enter the cost of the item: "))
        gst_rate = float(input("Enter the GST rate in percentage: "))

        gst_amount, total_cost = calculate_gst(cost, gst_rate)

        print(f"GST Amount: Rs{gst_amount:.2f}")
        print(f"Total Cost (Including GST): Rs{total_cost:.2f}")

    except ValueError:
        print("Invalid input. Please enter valid numeric values for cost and GST rate.")
# Out:
# Enter the cost of the item: 29454234
# Enter the GST rate in percentage: 15
# GST Amount: Rs4418135.10
# Total Cost (Including GST): Rs33872369.10

# %% [markdown]
# # **Explaination :**
#
# This program calculates the GST (Goods and Services Tax) amount and the total cost (including GST) for an item based on the given cost and GST rate.
#
#
# 1. The function `calculate_gst(cost, gst_rate)` takes two parameters `cost` and `gst_rate`, which represent the cost of the item and the GST rate in percentage, respectively.
#
# 2. Inside the function, the `gst_amount` is calculated by multiplying the `cost` by the `gst_rate` and then dividing the result by 100. This gives us the GST amount.
#
# 3. The `total_cost` is calculated by adding the `gst_amount` to the original `cost`.
#
# 4. The function then returns two values, `gst_amount` and `total_cost`.
#
# 5. In the `__main__` block, the program asks the user to enter the cost of the item and the GST rate in percentage using the `input()` function.
#
# 6. The `float()` function is used to convert the user input into floating-point numbers.
#
# 7. The program then calls the `calculate_gst(cost, gst_rate)` function and stores the returned values `gst_amount` and `total_cost` in variables.
#
# 8. The program then prints the calculated `gst_amount` and `total_cost` using formatted strings with two decimal places.
#
# 9. If the user enters invalid input (non-numeric values), the `ValueError` exception is caught using a `try-except` block, and an error message is displayed.

# %% [markdown]
# # Q4 Make A Program About The Zodiac Sign.

# %%
def zodiac_sign(day, month):

    if month == 'december':
        astro_sign = 'Sagittarius' if (day < 22) else 'Capricorn'

    elif month == 'january':
        astro_sign = 'Capricorn' if (day < 20) else 'Aquarius'

    elif month == 'february':
        astro_sign = 'Aquarius' if (day < 19) else 'Pisces'

    elif month == 'march':
        astro_sign = 'Pisces' if (day < 21) else 'Aries'

    elif month == 'april':
        astro_sign = 'Aries' if (day < 20) else 'Taurus'

    elif month == 'may':
        astro_sign = 'Taurus' if (day < 21) else 'Gemini'

    elif month == 'june':
        astro_sign = 'Gemini' if (day < 21) else 'Cancer'

    elif month == 'july':
        astro_sign = 'Cancer' if (day < 23) else 'Leo'

    elif month == 'august':
        astro_sign = 'Leo' if (day < 23) else 'Virgo'

    elif month == 'september':
        astro_sign = 'Virgo' if (day < 23) else 'Libra'

    elif month == 'october':
        astro_sign = 'Libra' if (day < 23) else 'Scorpio'

    elif month == 'november':
        astro_sign = 'Scorpio' if (day < 22) else 'Sagittarius'

    else:
        astro_sign = None

    if astro_sign:
        print(f"Your Zodiac Sign is: {astro_sign}")
    else:
        print("Invalid month name. Please enter a valid month name (e.g., january, february, etc.).")


if __name__ == '__main__':
    try:
        day = int(input("Enter Your Birth Date : "))
        month = input("Enter Your Birth Month: ").lower()
        zodiac_sign(day, month)
    except ValueError:
        print("Invalid input. Please enter valid numeric values for the day.")
# Out:
# Enter Your Birth Date : 19
# Enter Your Birth Month: may
# Your Zodiac Sign is: Taurus

# %% [markdown]
# # **Expalination :**
#
# 1. The program defines a function `zodiac_sign(day, month)` that takes two parameters: `day` (an integer representing the day of the birth date) and `month` (a string representing the name of the birth month).
#
# 2. Inside the function, there is a series of `if-elif` statements that check the given `month` and `day` against predefined date ranges for each zodiac sign. For example, if the `month` is "january" and the `day` is less than 20, the zodiac sign will be "Capricorn," otherwise, it will be "Aquarius."
#
# 3. The function uses the `astro_sign` variable to store the calculated zodiac sign. It is initialized to `None` at the beginning, which serves as a default value in case the provided `month` is not recognized.
#
# 4. If the provided `month` and `day` fall within one of the specified date ranges, the `astro_sign` variable will be assigned the corresponding zodiac sign.
#
# 5. After determining the `astro_sign`, the program checks if it is not `None`, which means a valid zodiac sign has been found. In that case, it prints the zodiac sign along with a friendly message: "Your Zodiac Sign is: {astro_sign}".
#
# 6. If the `astro_sign` is `None`, it means the entered `month` is not recognized or the `day` is out of range for the given `month`. In this case, the program prints a message: "Invalid month name. Please enter a valid month name (e.g., january, february, etc.)."
#
# 7. The program then uses a `try-except` block to handle any potential ValueError that may occur when converting the user input to integers.
#
# 8. The user is prompted to enter their birth date and month. The input for the `day` is expected to be an integer (1-31), and the input for the `month` is expected to be a string representing the name of the month (e.g., "january", "february", etc.). The month string is converted to lowercase using the `lower()` method to handle input with various letter cases.
#
# 9. The function `zodiac_sign(day, month)` is called with the provided input values. The function will then determine the zodiac sign based on the input and display the result or an error message, depending on the input validity.

# %% [markdown]
# # Q5 Make A Game Using Condition And Input Function.

# %%
import random

while True:
    user_action = input("Enter a choice (rock, paper, scissors): ")
    possible_actions = ["rock", "paper", "scissors"]
    computer_action = random.choice(possible_actions)
    print(f"\nYou chose {user_action}, computer chose {computer_action}.\n")

    if user_action == computer_action:
        print(f"Both players selected {user_action}. It's a tie!")
    elif user_action == "rock":
        if computer_action == "scissors":
            print("Rock smashes scissors! You win!")
        else:
            print("Paper covers rock! You lose.")
    elif user_action == "paper":
        if computer_action == "rock":
            print("Paper covers rock! You win!")
        else:
            print("Scissors cuts paper! You lose.")
    elif user_action == "scissors":
        if computer_action == "paper":
            print("Scissors cuts paper! You win!")
        else:
            print("Rock smashes scissors! You lose.")

    play_again = input("Play again? (y/n): ")
    if play_again.lower() != "y":
        break
# Out:
# Enter a choice (rock, paper, scissors): rock
#
# You chose rock, computer chose rock.
#
# Both players selected rock. It's a tie!
# Play again? (y/n): y
# Enter a choice (rock, paper, scissors): paper
#
# You chose paper, computer chose rock.
#
# Paper covers rock! You win!
# Play again? (y/n): n

# %% [markdown]
# # **Explaination :**
#
# 1. The program starts with a `while True` loop, meaning it will keep running until the user chooses to stop playing.
#
# 2. Inside the loop, the user is prompted to enter their choice (rock, paper, or scissors) using the `input()` function. The input is stored in the `user_action` variable.
#
# 3. A list `possible_actions` is defined, containing the three choices: "rock", "paper", and "scissors".
#
# 4. The computer's choice is randomly selected from `possible_actions` using the `random.choice()` function, and it is stored in the `computer_action` variable.
#
# 5. The program prints both the user's choice and the computer's choice using formatted strings.
#
# 6. The program then enters a series of `if-elif` statements to determine the winner based on the user's choice and the computer's choice. It checks for tie conditions, as well as the scenarios where the user wins or loses based on the rules of the game.
#
# 7. After determining the winner, the program asks the user if they want to play again by prompting for input with the message "Play again? (y/n):". The user's response is stored in the `play_again` variable.
#
# 8. If the user responds with anything other than "y" (not case-sensitive), the program breaks out of the `while True` loop, and the game ends.

# %% [markdown]
# # Q6 emp = ["A",25,"Z",55,"B",68, "K",15,"H", 18, "G",18,"R",26,"P",100,"N"]
#     emp[2:6]
#     emp[:6]
#     emp[1:5]
#     emp[4:4]
#     emp[2:10:4]
#     emp[:6:2]
#     Filter String And Integer Data.

# %%
emp = ["A",25,"Z",55,"B",68, "K",15,"H", 18, "G",18,"R",26,"P",100,"N"]

# %%
emp[2:6]
# Out:
# ['Z', 55, 'B', 68]

# %%
emp[:6]
# Out:
# ['A', 25, 'Z', 55, 'B', 68]

# %%
emp[1:5]
# Out:
# [25, 'Z', 55, 'B']

# %%
emp[4:4]
# Out:
# []

# %%
emp[2:10:4]
# Out:
# ['Z', 'K']

# %%
emp[:6:2]
# Out:
# ['A', 'Z', 'B']

# %%
# Filter string data
string_data = [item for item in emp if isinstance(item, str)]
print("String Data:", string_data)

# Filter integer data
integer_data = [item for item in emp if isinstance(item, int)]
print("Integer Data:", integer_data)
# Out:
# String Data: ['A', 'Z', 'B', 'K', 'H', 'G', 'R', 'P', 'N']
# Integer Data: [25, 55, 68, 15, 18, 18, 26, 100]

# %% [markdown]
# # Explanation:
#
# 1. The list `emp` contains a mix of strings and integers.
#
# 2. The first list comprehension `string_data` iterates through each element in `emp`, and it checks if the element is an instance of the `str` class using the `isinstance()` function. If the element is a string, it adds it to the `string_data` list. So, it filters and collects only the string data from the `emp` list.
#
# 3. The second list comprehension `integer_data` does the same but for integers. It iterates through each element in `emp`, checks if the element is an instance of the `int` class, and if so, it adds it to the `integer_data` list. Thus, it filters and collects only the integer data from the `emp` list.
#
# 4. The `print()` statements are used to display the filtered string and integer data.

# %% [markdown]
# # Q7 Make A New Class of All Methods of List And Add New Two Methods:
#     ⇒ Average ⇒ Type Cast (Tuple)

# %%
pip install colorama

# %%
class TypeCast:
    @staticmethod
    def list_to_tuple(lst):
        return tuple(lst)


def show_menu():
    print("\nAvailable List Methods:")
    print("1. append")
    print("2. clear")
    print("3. copy")
    print("4. count")
    print("5. extend")
    print("6. index")
    print("7. insert")
    print("8. pop")
    print("9. remove")
    print("10. reverse")
    print("11. sort")
    print("12. Average")
    print("13. Type Cast (to Tuple)")
    print("0. Exit")


def main():
    numbers = [2, 4, 6, 8, 10]

    while True:
        show_menu()
        choice = int(input("\nEnter your choice (0-13): "))

        if choice == 1:
            number = int(input("Enter the number to append: "))
            numbers.append(number)
            print("After append:", numbers)

        elif choice == 2:
            numbers.clear()
            print("After clear:", numbers)

        elif choice == 3:
            numbers_copy = numbers.copy()
            print("Copy of the list:", numbers_copy)

        elif choice == 4:
            value = int(input("Enter the value to count: "))
            count_value = numbers.count(value)
            print(f"Count of {value}: {count_value}")

        elif choice == 5:
            extend_list = input("Enter a list to extend (comma-separated values): ").split(',')
            extend_list = [int(item) for item in extend_list]
            numbers.extend(extend_list)
            print("After extend:", numbers)

        elif choice == 6:
            value = int(input("Enter the value to find its index: "))
            index_value = numbers.index(value)
            print(f"Index of {value}: {index_value}")

        elif choice == 7:
            value = int(input("Enter the value to insert: "))
            index = int(input("Enter the index to insert at: "))
            numbers.insert(index, value)
            print("After insert:", numbers)

        elif choice == 8:
            popped_element = numbers.pop()
            print("Popped element:", popped_element)
            print("After pop:", numbers)

        elif choice == 9:
            value = int(input("Enter the value to remove: "))
            numbers.remove(value)
            print("After remove:", numbers)

        elif choice == 10:
            numbers.reverse()
            print("After reverse:", numbers)

        elif choice == 11:
            numbers.sort()
            print("After sort:", numbers)

        elif choice == 12:
            average = sum(numbers) / len(numbers)
            print("Average:", average)

        elif choice == 13:
            type_cast = TypeCast()
            tuple_numbers = type_cast.list_to_tuple(numbers)
            print("Tuple representation of the list:", tuple_numbers)

        elif choice == 0:
            print("Exiting the program.")
            break

        else:
            print("Invalid choice. Please enter a valid choice.")


if __name__ == "__main__":
    main()
# Out:
# Available List Methods:
# 1. append
# 2. clear
# 3. copy
# 4. count
# 5. extend
# 6. index
# 7. insert
# 8. pop
# 9. remove
# 10. reverse
# 11. sort
# 12. Average
# 13. Type Cast (to Tuple)
# 0. Exit
#
# Enter your choice (0-13): 3
# Copy of the list: [2, 4, 6, 8, 10]
#
# Available List Methods:
# 1. append
# 2. clear
# 3. copy
# 4. count
# 5. extend
# 6. index
# 7. insert
# 8. pop
# 9. remove
# 10. reverse
# 11. sort
# 12. Average
# 13. Type Cast (to Tuple)
# 0. Exit
#
# Enter your choice (0-13): 2
# After clear: []
#
# Available List Methods:
# 1. append
# 2. clear
# 3. copy
# 4. count
# 5. extend
# 6. index
# 7. insert
# 8. pop
# 9. remove
# 10. reverse
# 11. sort
# 12. Average
# 13. Type Cast (to Tuple)
# 0. Exit
#
# Enter your choice (0-13): 0
# Exiting the program.

# %% [markdown]
# # **Explaination :**
#
# The above code is a Python program that allows the user to interact with a list of numbers. The user can perform various operations on the list, such as appending elements, clearing the list, counting occurrences of a value, extending the list with new elements, finding the index of a value, inserting a value at a specific index, popping an element, removing a value, reversing the list, sorting the list, calculating the average of elements, and converting the list to a tuple. The user can choose from a menu of options to perform these operations.
#
# Let's break down the code and its functionality:
#
# 1. The `TypeCast` class:
#    - This class contains a static method `list_to_tuple(lst)` that converts a given list `lst` to a tuple. This method is used later in the program to convert the list of numbers to a tuple representation.
#
# 2. The `show_menu()` function:
#    - This function displays a menu of available list methods that the user can choose from. It prints a list of options, each corresponding to one of the available operations on the list.
#
# 3. The `main()` function:
#    - The main function is the entry point of the program. It initializes a list named `numbers` with some initial values: `[2, 4, 6, 8, 10]`.
#    - It then enters a loop that displays the menu using the `show_menu()` function and takes user input for their choice.
#    - Based on the user's choice, the program executes the corresponding list operation.
#    - The user can continue choosing options from the menu until they choose option 0 to exit the program.
#
# 4. List Operations:
#    - When the user selects an option from the menu, the program performs the following actions based on the chosen option:
#      - Option 1: `append()` - The program takes a number from the user and appends it to the list.
#      - Option 2: `clear()` - The program clears all elements from the list.
#      - Option 3: `copy()` - The program creates a copy of the list.
#      - Option 4: `count()` - The program takes a value from the user and counts its occurrences in the list.
#      - Option 5: `extend()` - The program takes a list of comma-separated numbers from the user and extends the original list with these values.
#      - Option 6: `index()` - The program takes a value from the user and finds its index in the list.
#      - Option 7: `insert()` - The program takes a value and an index from the user and inserts the value at the specified index in the list.
#      - Option 8: `pop()` - The program removes the last element from the list and prints the popped element.
#      - Option 9: `remove()` - The program takes a value from the user and removes its first occurrence from the list.
#      - Option 10: `reverse()` - The program reverses the elements in the list.
#      - Option 11: `sort()` - The program sorts the elements of the list in ascending order.
#      - Option 12: `Average` - The program calculates and prints the average of the elements in the list.
#      - Option 13: `Type Cast (to Tuple)` - The program uses the `TypeCast` class to convert the list to a tuple and prints the tuple representation.
#
# 5. Exiting the Program:
#    - If the user chooses option 0, the program prints a message indicating that it is exiting, and the loop terminates, ending the program.

# %% [markdown]
# # Q8 Make A Function About The Tkinter Module.

# %%
import tkinter as tk

def on_button_click():
    label.config(text="m=tkinter.Tk() where m is the name of the main window object")

# Create the main window
root = tk.Tk()

# Set the window title
root.title("Tkinter Basics")

window_width = 500
window_height = 300
screen_width = root.winfo_screenwidth()
screen_height = root.winfo_screenheight()
x_position = (screen_width - window_width) // 2
y_position = (screen_height - window_height) // 2
root.geometry(f"{window_width}x{window_height}+{x_position}+{y_position}")

# Set the window background color
root.configure(bg="#f0f0f0")

# Add a label to the window
label = tk.Label(root, text=''' Tkinter is a Python library used to create graphical user interfaces (GUIs). ''', font=("Arial", 20))
label.pack(pady=20)

# Add a button to the window
button = tk.Button(root, text="Basic Code", command=on_button_click)
button.pack()

# Start the Tkinter main event loop
root.mainloop()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# # Explaination :
#
# 1. Import the `tkinter` module under the alias `tk`.
# 2. Define the function `on_button_click`, which will be called when the button is clicked. In this function, it updates the text of the `label` widget with a specific message.
# 3. Create the main window using `tk.Tk()` and store it in the variable `root`.
# 4. Set the window title to "Tkinter Basics."
# 5. Calculate the window position and set the size and position of the window on the screen.
# 6. Set the background color of the window to a light gray color (`#f0f0f0`).
# 7. Add a label widget to the window with a specific text and font.
# 8. Add a button widget to the window with the label "Basic Code" and set the command to `on_button_click`, which means the function `on_button_click` will be called when the button is clicked.
# 9. Start the main event loop using `root.mainloop()`. This loop allows the window to respond to user interactions and events, such as button clicks.

# %% [markdown]
# # Q9 Make A Program About Store Image In MySQL.

# %%
import mysql.connector

def read_image(file_path):
    with open(file_path, 'rb') as file:
        return file.read()

def store_image_in_mysql(image_data):
    connection = mysql.connector.connect(
        host='localhost',
        user='root',
        password='root',
        database='student'
    )

    cursor = connection.cursor()

    # Create a table to store images (if not already exists)
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS images (
            id INT AUTO_INCREMENT PRIMARY KEY,
            image_data LONGBLOB
        )
    ''')

    # Insert the image data into the table
    insert_query = 'INSERT INTO images (image_data) VALUES (%s)'
    cursor.execute(insert_query, (image_data,))

    connection.commit()
    connection.close()

if __name__ == "__main__":
    file_path = input("Enter file path : ")
    image_data = read_image(file_path)
    store_image_in_mysql(image_data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-791bed9fb517> in <cell line: 1>()
# ----> 1 import mysql.connector
#       2
#       3 def read_image(file_path):
#       4     with open(file_path, 'rb') as file:
#       5         return file.read()
#
# ModuleNotFoundError: No module named 'mysql'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # **Explaination :**
#
# 1. `import mysql.connector`: This line imports the `mysql.connector` module, which allows us to connect and interact with a MySQL database.
#
# 2. `def read_image(file_path):`: This function takes a file path as input and reads the binary data of the image file.
#
# 3. `with open(file_path, 'rb') as file: ...`: This opens the image file specified by the `file_path` in binary read mode ('rb'). The `with` statement ensures that the file is automatically closed after the block of code inside it executes.
#
# 4. `return file.read()`: This reads the binary data from the file and returns it. The binary data represents the content of the image.
#
# 5. `def store_image_in_mysql(image_data):`: This function takes the binary `image_data` as input and stores it in the MySQL database.
#
# 6. `connection = mysql.connector.connect(...`: This establishes a connection to the MySQL server using the specified parameters like host, user, password, and database.
#
# 7. `cursor = connection.cursor()`: This creates a cursor object to interact with the MySQL database.
#
# 8. `cursor.execute(''' ... ''')`: This executes an SQL query using the cursor. The query creates a table named `images` in the specified database (`student` in this case) if it does not already exist. The table has two columns: `id` (an auto-incrementing primary key) and `image_data` (a `LONGBLOB` data type to store the binary image data).
#
# 9. `insert_query = 'INSERT INTO images (image_data) VALUES (%s)'`: This defines an SQL query that inserts the `image_data` into the `images` table.
#
# 10. `cursor.execute(insert_query, (image_data,))`: This executes the insert query with the `image_data` as a parameter. The data is inserted into the `image_data` column of the `images` table.
#
# 11. `connection.commit()`: This commits the changes made to the database, making the image data permanent.
#
# 12. `connection.close()`: This closes the connection to the MySQL server.
#
# 13. `if __name__ == "__main__":`: This block of code is executed when the script is run directly (not imported as a module).
#
# 14. `file_path = input("Enter file path : ")`: This prompts the user to enter the file path of the image they want to store.
#
# 15. `image_data = read_image(file_path)`: The `read_image()` function is called to read the binary data of the image file.
#
# 16. `store_image_in_mysql(image_data)`: The `store_image_in_mysql()` function is called with the binary `image_data` obtained from the file. The image data is then stored in the MySQL database.

# %% [markdown]
# # Q10 Make A Function About Explain of:
#     1. Big Data
#     2. IOT

# %%
def explain_big_data():
    big_data_explanation = """
    Big Data:
    Big Data refers to the vast volume of structured, semi-structured, and unstructured data that is generated at a high velocity and cannot be easily managed and processed by traditional data processing applications. It encompasses data from various sources, such as social media, sensors, devices, transactions, and more. Big Data is characterized by the three Vs:

    1. Volume: Big Data involves a massive amount of data that is beyond the processing capabilities of traditional databases and tools.

    2. Velocity: Data in the Big Data domain is generated at an extremely high speed, making real-time processing and analysis necessary.

    3. Variety: Big Data includes data in different formats, including text, images, videos, log files, and more.

    Big Data technologies and techniques, such as Hadoop, Apache Spark, NoSQL databases, and data mining algorithms, are used to store, process, and analyze this vast amount of data. Organizations utilize Big Data to gain valuable insights, make data-driven decisions, and improve business processes and customer experiences.
    """
    return big_data_explanation

def explain_iot():
    iot_explanation = """
    Internet of Things (IoT):
    The Internet of Things (IoT) is a network of interconnected physical objects or devices that are embedded with sensors, software, and other technologies, enabling them to collect and exchange data over the internet without human intervention. These devices can range from everyday objects like home appliances and wearable devices to industrial machines and smart city infrastructure.

    Key features of IoT:

    1. Connectivity: IoT devices are connected to the internet or other networks, allowing them to communicate with each other and with centralized systems.

    2. Data Collection: IoT devices collect data from their surroundings through sensors, cameras, or other data-capturing mechanisms.

    3. Automation: IoT enables automation and remote control of devices, improving efficiency and convenience.

    4. Data Analysis: Collected data is processed and analyzed to derive meaningful insights and enable data-driven decisions.

    The applications of IoT are vast, ranging from smart homes and wearable devices to industrial automation, healthcare, agriculture, transportation, and more. IoT technology has the potential to revolutionize various industries by enhancing efficiency, reducing costs, and providing innovative services and products.
    """
    return iot_explanation

def main():
    print("1. Big Data:")
    print(explain_big_data())
    print("\n2. Internet of Things (IoT):")
    print(explain_iot())

if __name__ == "__main__":
    main()
# Out:
# 1. Big Data:
#
#     Big Data:
#     Big Data refers to the vast volume of structured, semi-structured, and unstructured data that is generated at a high velocity and cannot be easily managed and processed by traditional data processing applications. It encompasses data from various sources, such as social media, sensors, devices, transactions, and more. Big Data is characterized by the three Vs:
#
#     1. Volume: Big Data involves a massive amount of data that is beyond the processing capabilities of traditional databases and tools.
#
#     2. Velocity: Data in the Big Data domain is generated at an extremely high speed, making real-time processing and analysis necessary.
#
#     3. Variety: Big Data includes data in different formats, including text, images, videos, log files, and more.
#
# ...
